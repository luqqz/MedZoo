# %%
import matplotlib.pyplot as plt
import SimpleITK

#from MedicalDataset import *

# %%
spleen = SimpleITK.ReadImage('E:/Studia/MGR/MedZoo/data_final_processed/spleen/train/8_spleen_ct.nii.gz')
spleen = SimpleITK.GetArrayFromImage(spleen)
liver = SimpleITK.ReadImage('E:/Studia/MGR/MedZoo/data_final_processed/liver/train/8_liver_ct.nii')
liver = SimpleITK.GetArrayFromImage(liver)
kidney = SimpleITK.ReadImage('E:/Studia/MGR/MedZoo/data_final_processed/kidney/train/00003_kidney_ct.nii.gz')
kidney = SimpleITK.GetArrayFromImage(kidney)

plt.subplot(3, 3, 1)
plt.imshow(spleen[32, :, :])
plt.subplot(3, 3, 2)
plt.imshow(spleen[:, 32, :])
plt.subplot(3, 3, 3)
plt.imshow(spleen[:, :, 32])

plt.subplot(3, 3, 4)
plt.imshow(liver[32, :, :])
plt.subplot(3, 3, 5)
plt.imshow(liver[:, 32, :])
plt.subplot(3, 3, 6)
plt.imshow(liver[:, :, 32])

plt.subplot(3, 3, 7)
plt.imshow(kidney[32, :, :])
plt.subplot(3, 3, 8)
plt.imshow(kidney[:, 32, :])
plt.subplot(3, 3, 9)
plt.imshow(kidney[:, :, 32])

plt.show()

# md = MedicalDataset()

# for ex in md.get_generator():
#     plt.subplot(1, 2, 1)
#     plt.imshow(ex['data'][32, :, :])

#     plt.subplot(1,2,2)
#     plt.imshow(ex['mask'][32, :, :])
#     plt.show()
