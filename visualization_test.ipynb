# %%
import matplotlib.pyplot as plt

from MedicalDataset import *

# %%
md = MedicalDataset()

for ex in md.get_generator():
    plt.subplot(1, 2, 1)
    plt.imshow(ex['data'][32, :, :])

    plt.subplot(1,2,2)
    plt.imshow(ex['mask'][32, :, :])
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# <ipython-input-4-3e879fc45968> in <module>
#       1 md = MedicalDataset()
#       2
# ----> 3 for ex in md.get_generator():
#       4     plt.subplot(1, 2, 1)
#       5     plt.imshow(ex['data'][32, :, :])
#
# E:\Studia\MGR\MedZoo\MedicalDataset.py in get_generator(self)
#     256
#     257             for i in range(len(shuffled_list)):
# --> 258                 image, mask, task = self.__getitem__(shuffled_list[i])
#     259                 image = image[0, :, :, :]
#     260                 mask = mask[0, :, :, :]
#
# E:\Studia\MGR\MedZoo\MedicalDataset.py in __getitem__(self, index)
#     237             mask_data = mask_data.transpose((2, 1, 0))
#     238
# --> 239         height, width, depth = self.locate_boundaries(mask_data, index)
#     240         image_data = image_data[depth[0]:depth[1], height[0]: height[1], width[0]: width[1]]
#     241         mask_data = mask_data[depth[0]:depth[1], height[0]: height[1], width[0]: width[1]]
#
# E:\Studia\MGR\MedZoo\MedicalDataset.py in locate_boundaries(self, mask, index)
#     119             if boundary_w_min < 0:
#     120                 boundary_w_min = 0
# --> 121                 boundary_w_max = numpy.min(self.target_size[1], img_w)
#     122
#     123         if (boundary_d_max - boundary_d_min) < self.target_size[2]:
#
# <__array_function__ internals> in amin(*args, **kwargs)
#
# c:\users\luqz\appdata\local\programs\python\python38\lib\site-packages\numpy\core\fromnumeric.py in amin(a, axis, out, keepdims, initial, where)
#    2828     6
#    2829     """
# -> 2830     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
#    2831                           keepdims=keepdims, initial=initial, where=where)
#    2832
#
# c:\users\luqz\appdata\local\programs\python\python38\lib\site-packages\numpy\core\fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85                 return reduction(axis=axis, out=out, **passkwargs)
#      86
# ---> 87     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      88
#      89
#
# AxisError: axis 186 is out of bounds for array of dimension 0
