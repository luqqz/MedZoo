# %%
# !pip install -e .
# !pip install --upgrade git+https://github.com/FabianIsensee/hiddenlayer.git@more_plotted_details#egg=hiddenlayer
# Out:
# Obtaining file:///notebooks/nnUNet
# ...
#      |████████████████████████████████| 151 kB 11.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 57 kB 6.7 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 171 kB 33.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.0 MB 30.8 MB/s eta 0:00:01
# ...
#   Created wheel for dicom2nifti: filename=dicom2nifti-2.3.0-py3-none-any.whl size=42933 sha256=15f0fbc8347884e05b7231ec011e6c04296329c1ffc239a42b4b6b1ed82de906
#   Stored in directory: /root/.cache/pip/wheels/8f/bb/8f/084918b342d2616c5fc804ec689dac30273c9d11d6aa30f689
# ...
#   Created wheel for medpy: filename=MedPy-0.4.0-py3-none-any.whl size=214958 sha256=83226dc9d47009c18dde02455d8bd3ca0afbd576cc82a49e5f9f13a1f0999c07
#   Stored in directory: /root/.cache/pip/wheels/fc/38/7d/e0b8bcb2770f779a93cab5ab7fa6dd344011e1278cb90cab86
# ...

# %%
# !apt-get install zip
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   zip
# 0 upgraded, 1 newly installed, 0 to remove and 55 not upgraded.
# Need to get 167 kB of archives.
# After this operation, 638 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/main amd64 zip amd64 3.0-11build1 [167 kB]
# Fetched 167 kB in 0s (397 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# Selecting previously unselected package zip.
# (Reading database ... 36445 files and directories currently installed.)
# Preparing to unpack .../zip_3.0-11build1_amd64.deb ...
# Unpacking zip (3.0-11build1) ...
# Setting up zip (3.0-11build1) ...

# %%
# nnUNet
#predict
# %cd "/notebooks/nnUNet/"
# !nnUNet_raw_data_base="/notebooks/nnUNet/nnUNet_raw_data_base" nnUNet_preprocessed="/notebooks/nnUNet/nnUNet_preprocessed" RESULTS_FOLDER="/notebooks/nnUNet/nnUNet_trained_models" nnUNet_predict -i "/notebooks/val_data/imagesTs" -o "/notebooks/output_all_2d" -chk model_best -tr nnUNetTrainerV2 -m 2d -p nnUNetPlansv2.1 -t Task999_SLK
# Out:
# /notebooks/nnUNet
#
#
# Please cite the following paper when using nnUNet:
#
# Isensee, F., Jaeger, P.F., Kohl, S.A.A. et al. "nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation." Nat Methods (2020). https://doi.org/10.1038/s41592-020-01008-z
#
#
# If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet
#
# using model stored in  /notebooks/nnUNet/nnUNet_trained_models/nnUNet/2d/Task999_SLK/nnUNetTrainerV2__nnUNetPlansv2.1
# This model expects 1 input modalities for each image
# Found 30 unique case ids, here are some examples: ['img0038' 'img0039' 'img0038' 'img0001' 'img0004' 'img0007' 'img0034'
#  'img0024' 'img0039' 'img0036']
# If they don't look right, make sure to double check your filenames. They must end with _0000.nii.gz etc
# number of cases: 30
# number of cases that still need to be predicted: 30
# emptying cuda cache
# loading parameters for folds, None
# ...

# %%
# 1nnUNet
#predict
# %cd "/notebooks/1nnUNet/"
# !nnUNet_raw_data_base="/notebooks/1nnUNet/nnUNet_raw_data_base" nnUNet_preprocessed="/notebooks/1nnUNet/nnUNet_preprocessed" RESULTS_FOLDER="/notebooks/1nnUNet/nnUNet_trained_models" nnUNet_predict -i "/notebooks/val_data2" -o "/notebooks/output_spl_33D2" -chk model_best -tr nnUNetTrainerV2 -m 3d_fullres -p nnUNetPlansv2.1 -t Task009_Spleen
# Out:
# /notebooks/1nnUNet
#
#
# Please cite the following paper when using nnUNet:
#
# Isensee, F., Jaeger, P.F., Kohl, S.A.A. et al. "nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation." Nat Methods (2020). https://doi.org/10.1038/s41592-020-01008-z
#
#
# If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet
#
# using model stored in  /notebooks/1nnUNet/nnUNet_trained_models/nnUNet/3d_fullres/Task009_Spleen/nnUNetTrainerV2__nnUNetPlansv2.1
# This model expects 1 input modalities for each image
# Found 5 unique case ids, here are some examples: ['img0037' 'img0037' 'img0009' 'img0037' 'img0003']
# If they don't look right, make sure to double check your filenames. They must end with _0000.nii.gz etc
# number of cases: 5
# number of cases that still need to be predicted: 5
# emptying cuda cache
# loading parameters for folds, None
# ...

# %%
# !rm -rf /notebooks/1nnUNet/nnUNet_trained_models/nnUNet/3d_fullres/Task999_SLK/nnUNetTrainerV2__nnUNetPlansv2.1/fold_0
