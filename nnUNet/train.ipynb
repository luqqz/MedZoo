# %%
# !pip install -e .
# !pip install --upgrade git+https://github.com/FabianIsensee/hiddenlayer.git@more_plotted_details#egg=hiddenlayer
# Out:
# Obtaining file:///notebooks/nnUNet
# ...
#      |████████████████████████████████| 151 kB 39.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 57 kB 10.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 171 kB 56.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.0 MB 59.5 MB/s eta 0:00:01
# ...
#   Created wheel for dicom2nifti: filename=dicom2nifti-2.3.0-py3-none-any.whl size=42933 sha256=31872064b8ae88d84f057154a596c4c38762b677cb36512ac412924190b90227
#   Stored in directory: /root/.cache/pip/wheels/8f/bb/8f/084918b342d2616c5fc804ec689dac30273c9d11d6aa30f689
# ...
#   Created wheel for medpy: filename=MedPy-0.4.0-py3-none-any.whl size=214958 sha256=7f0abbb8bf4884d5ec2b1cd3e19059a1c18b498e6cb0e8d92118c8a93db60976
#   Stored in directory: /root/.cache/pip/wheels/fc/38/7d/e0b8bcb2770f779a93cab5ab7fa6dd344011e1278cb90cab86
# ...

# %%
#preprocess
# !nnUNet_raw_data_base="/notebooks/nnUNet/nnUNet_raw_data_base" nnUNet_preprocessed="/notebooks/nnUNet/nnUNet_preprocessed" RESULTS_FOLDER="/notebooks/nnUNet/nnUNet_trained_models" nnUNet_plan_and_preprocess -tl 4 -tf 4 -t 999
# Out:
# Please cite the following paper when using nnUNet:
#
# Isensee, F., Jaeger, P.F., Kohl, S.A.A. et al. "nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation." Nat Methods (2020). https://doi.org/10.1038/s41592-020-01008-z
#
#
# If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet
#
# slk_000
# slk_024
# slk_048
# slk_072
# before crop: (1, 75, 512, 512) after crop: (1, 35, 326, 326) spacing: [5.       0.703125 0.703125]
#
# before crop: (1, 93, 512, 512) after crop: (1, 67, 381, 363) spacing: [2.5        0.67773402 0.67773402]
#
# slk_001
# before crop: (1, 123, 512, 512) after crop: (1, 38, 348, 348) spacing: [5.         0.67578101 0.67578101]
#
# slk_073
# before crop: (1, 244, 512, 512) after crop: (1, 78, 325, 325) spacing: [2.5        0.97656202 0.97656202]
#
# before crop: (1, 276, 512, 512) after crop: (1, 127, 386, 386) spacing: [1.5        0.66992188 0.66992188]
#
# slk_002
# ...

# %%
#train
# !nnUNet_raw_data_base="/notebooks/nnUNet/nnUNet_raw_data_base" nnUNet_preprocessed="/notebooks/nnUNet/nnUNet_preprocessed" RESULTS_FOLDER="/notebooks/nnUNet/nnUNet_trained_models" nnUNet_train 2d nnUNetTrainerV2 Task999_SLK 0 -c --npz
# Out:
# Please cite the following paper when using nnUNet:
#
# Isensee, F., Jaeger, P.F., Kohl, S.A.A. et al. "nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation." Nat Methods (2020). https://doi.org/10.1038/s41592-020-01008-z
#
#
# If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet
#
# ###############################################
# I am running the following nnUNet: 2d
# My trainer class is:  <class 'nnunet.training.network_training.nnUNetTrainerV2.nnUNetTrainerV2'>
# For that I will be using the following configuration:
# num_classes:  3
# modalities:  {0: 'CT'}
# use_mask_for_norm OrderedDict([(0, False)])
# keep_only_largest_region None
# min_region_size_per_class None
# min_size_per_class None
# normalization_schemes OrderedDict([(0, 'CT')])
# stages...
#
# stage:  0
# ...

# %%
# !pwd
# Out:
# /notebooks/nnUNet
